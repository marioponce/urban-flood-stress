# %%
import hashlib
import logging
import os
import time
from datetime import date
from pathlib import Path

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from IPython.display import display
from shapely import make_valid
from shapely.ops import unary_union

MPLCONFIGDIR = Path('/tmp/matplotlib')
MPLCONFIGDIR.mkdir(parents=True, exist_ok=True)
os.environ.setdefault('MPLCONFIGDIR', str(MPLCONFIGDIR))
plt.style.use('seaborn-v0_8-whitegrid')

# %%
tides = pd.read_parquet('../data/temporal/noaa/tide_series.parquet')

# %%
tides = tides[tides['station_id'].isin(['8516945','8518750','8531680'])]

# %%
tides
# Out:
#                  timestamp  raw_value_ft source_product value_unit station_id  \
# 0      2010-01-01 00:00:00         0.472  hourly_height         ft    8516945
# 1      2010-01-01 01:00:00         3.858  hourly_height         ft    8516945
# 2      2010-01-01 02:00:00         6.998  hourly_height         ft    8516945
# 3      2010-01-01 03:00:00         8.110  hourly_height         ft    8516945
# 4      2010-01-01 04:00:00         8.163  hourly_height         ft    8516945
# ...                    ...           ...            ...        ...        ...
# 426166 2026-03-31 19:00:00         0.350  hourly_height         ft    8531680
# 426167 2026-03-31 20:00:00         1.613  hourly_height         ft    8531680
# 426168 2026-03-31 21:00:00         2.853  hourly_height         ft    8531680
# 426169 2026-03-31 22:00:00         3.995  hourly_height         ft    8531680
# 426170 2026-03-31 23:00:00         4.828  hourly_height         ft    8531680
#
#        station_name     role      lat      lon state station_type  \
# 0       Kings Point  primary  40.8103 -73.7649    NY         None
# 1       Kings Point  primary  40.8103 -73.7649    NY         None
# 2       Kings Point  primary  40.8103 -73.7649    NY         None
# 3       Kings Point  primary  40.8103 -73.7649    NY         None
# 4       Kings Point  primary  40.8103 -73.7649    NY         None
# ...             ...      ...      ...      ...   ...          ...
# 426166   Sandy Hook  primary  40.4669 -74.0094    NJ         None
# 426167   Sandy Hook  primary  40.4669 -74.0094    NJ         None
# 426168   Sandy Hook  primary  40.4669 -74.0094    NJ         None
# 426169   Sandy Hook  primary  40.4669 -74.0094    NJ         None
# 426170   Sandy Hook  primary  40.4669 -74.0094    NJ         None
#
#        bridge_clearance_ft measurement_kind  tide_level_ft      series_kind
# 0                     None   water_level_ft          0.472  observed_hourly
# 1                     None   water_level_ft          3.858  observed_hourly
# 2                     None   water_level_ft          6.998  observed_hourly
# 3                     None   water_level_ft          8.110  observed_hourly
# 4                     None   water_level_ft          8.163  observed_hourly
# ...                    ...              ...            ...              ...
# 426166                None   water_level_ft          0.350  observed_hourly
# 426167                None   water_level_ft          1.613  observed_hourly
# 426168                None   water_level_ft          2.853  observed_hourly
# 426169                None   water_level_ft          3.995  observed_hourly
# 426170                None   water_level_ft          4.828  observed_hourly
#
# [426171 rows x 15 columns]
