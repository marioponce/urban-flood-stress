# %%
import hashlib
import logging
import os
import time
from datetime import date
from pathlib import Path

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from IPython.display import display
from shapely import make_valid
from shapely.ops import unary_union

MPLCONFIGDIR = Path('/tmp/matplotlib')
MPLCONFIGDIR.mkdir(parents=True, exist_ok=True)
os.environ.setdefault('MPLCONFIGDIR', str(MPLCONFIGDIR))
plt.style.use('seaborn-v0_8-whitegrid')

# %%
tides = pd.read_parquet('../data/temporal/noaa/tide_series.parquet')

# %%
tides.columns
# Out:
# Index(['timestamp', 'raw_value_ft', 'source_product', 'value_unit',
#        'station_id', 'station_name', 'role', 'lat', 'lon', 'state',
#        'station_type', 'bridge_clearance_ft', 'measurement_kind',
#        'tide_level_ft', 'series_kind'],
#       dtype='str')
